# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import re
import nltk
from nltk.corpus import stopwords
from nltk.stem.porter import PorterStemmer
import sklearn
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score

# %%
df = pd.read_csv('WELFake_Dataset.csv')
df
# Out:
#        Unnamed: 0                                              title  \
# 0               0  LAW ENFORCEMENT ON HIGH ALERT Following Threat...
# 1               1                                                NaN
# 2               2  UNBELIEVABLE! OBAMA’S ATTORNEY GENERAL SAYS MO...
# 3               3  Bobby Jindal, raised Hindu, uses story of Chri...
# 4               4  SATAN 2: Russia unvelis an image of its terrif...
# ...           ...                                                ...
# 72129       72129  Russians steal research on Trump in hack of U....
# 72130       72130   WATCH: Giuliani Demands That Democrats Apolog...
# 72131       72131  Migrants Refuse To Leave Train At Refugee Camp...
# 72132       72132  Trump tussle gives unpopular Mexican leader mu...
# 72133       72133  Goldman Sachs Endorses Hillary Clinton For Pre...
#
#                                                     text  label
# 0      No comment is expected from Barack Obama Membe...      1
# 1         Did they post their votes for Hillary already?      1
# 2       Now, most of the demonstrators gathered last ...      1
# 3      A dozen politically active pastors came here f...      0
# 4      The RS-28 Sarmat missile, dubbed Satan 2, will...      1
# ...                                                  ...    ...
# 72129  WASHINGTON (Reuters) - Hackers believed to be ...      0
# 72130  You know, because in fantasyland Republicans n...      1
# 72131  Migrants Refuse To Leave Train At Refugee Camp...      0
# 72132  MEXICO CITY (Reuters) - Donald Trump’s combati...      0
# 72133  Goldman Sachs Endorses Hillary Clinton For Pre...      1
#
# [72134 rows x 4 columns]

# %%
df.describe()
# Out:
#          Unnamed: 0         label
# count  72134.000000  72134.000000
# mean   36066.500000      0.514404
# std    20823.436496      0.499796
# min        0.000000      0.000000
# 25%    18033.250000      0.000000
# 50%    36066.500000      1.000000
# 75%    54099.750000      1.000000
# max    72133.000000      1.000000

# %%
df.shape
# Out:
# (72134, 4)

# %%
df['label'].value_counts()
# Out:
# label
# 1    37106
# 0    35028
# Name: count, dtype: int64

# %%
fake_count = df[df['label'] == 0].shape[0]
real_count = df[df['label'] == 1].shape[0]
labels = ['Fake', 'Real']
counts = [fake_count, real_count]

plt.bar(labels, counts, color=['blue', 'pink'])
plt.xlabel('News Type')
plt.ylabel('Count')
plt.title('Fake vs Real News Count')
plt.show()

# %%
df.describe()
# Out:
#          Unnamed: 0         label
# count  72134.000000  72134.000000
# mean   36066.500000      0.514404
# std    20823.436496      0.499796
# min        0.000000      0.000000
# 25%    18033.250000      0.000000
# 50%    36066.500000      1.000000
# 75%    54099.750000      1.000000
# max    72133.000000      1.000000

# %%
df.isnull().sum()
# Out:
# Unnamed: 0      0
# title         558
# text           39
# label           0
# dtype: int64

# %%
sns.heatmap(df.isnull(),yticklabels = False)
# Out:
# <Axes: >

# %%
df=df.fillna(' ')

# %%
df.isnull().sum()
# Out:
# Unnamed: 0    0
# title         0
# text          0
# label         0
# dtype: int64

# %%
df.drop(["Unnamed: 0"], axis=1, inplace=True)

# %%
df.head()
# Out:
#                                                title  \
# 0  LAW ENFORCEMENT ON HIGH ALERT Following Threat...
# 1
# 2  UNBELIEVABLE! OBAMA’S ATTORNEY GENERAL SAYS MO...
# 3  Bobby Jindal, raised Hindu, uses story of Chri...
# 4  SATAN 2: Russia unvelis an image of its terrif...
#
#                                                 text  label
# 0  No comment is expected from Barack Obama Membe...      1
# 1     Did they post their votes for Hillary already?      1
# 2   Now, most of the demonstrators gathered last ...      1
# 3  A dozen politically active pastors came here f...      0
# 4  The RS-28 Sarmat missile, dubbed Satan 2, will...      1

# %%
df["training_feature"] = df["title"] + df["text"]
df.head()
# Out:
#                                                title  \
# 0  LAW ENFORCEMENT ON HIGH ALERT Following Threat...
# 1
# 2  UNBELIEVABLE! OBAMA’S ATTORNEY GENERAL SAYS MO...
# 3  Bobby Jindal, raised Hindu, uses story of Chri...
# 4  SATAN 2: Russia unvelis an image of its terrif...
#
#                                                 text  label  \
# 0  No comment is expected from Barack Obama Membe...      1
# 1     Did they post their votes for Hillary already?      1
# 2   Now, most of the demonstrators gathered last ...      1
# 3  A dozen politically active pastors came here f...      0
# 4  The RS-28 Sarmat missile, dubbed Satan 2, will...      1
#
#                                     training_feature
# 0  LAW ENFORCEMENT ON HIGH ALERT Following Threat...
# 1     Did they post their votes for Hillary already?
# 2  UNBELIEVABLE! OBAMA’S ATTORNEY GENERAL SAYS MO...
# 3  Bobby Jindal, raised Hindu, uses story of Chri...
# 4  SATAN 2: Russia unvelis an image of its terrif...

# %%
df=df[['training_feature','label']]
df
# Out:
#                                         training_feature  label
# 0      LAW ENFORCEMENT ON HIGH ALERT Following Threat...      1
# 1         Did they post their votes for Hillary already?      1
# 2      UNBELIEVABLE! OBAMA’S ATTORNEY GENERAL SAYS MO...      1
# 3      Bobby Jindal, raised Hindu, uses story of Chri...      0
# 4      SATAN 2: Russia unvelis an image of its terrif...      1
# ...                                                  ...    ...
# 72129  Russians steal research on Trump in hack of U....      0
# 72130   WATCH: Giuliani Demands That Democrats Apolog...      1
# 72131  Migrants Refuse To Leave Train At Refugee Camp...      0
# 72132  Trump tussle gives unpopular Mexican leader mu...      0
# 72133  Goldman Sachs Endorses Hillary Clinton For Pre...      1
#
# [72134 rows x 2 columns]

# %%
dfFake = df[df['label'] == 0]
dfFake
# Out:
#                                         training_feature  label
# 3      Bobby Jindal, raised Hindu, uses story of Chri...      0
# 11     May Brexit offer would hurt, cost EU citizens ...      0
# 12     Schumer calls on Trump to appoint official to ...      0
# 14     No Change Expected for ESPN Political Agenda D...      0
# 15     Billionaire Odebrecht in Brazil scandal releas...      0
# ...                                                  ...    ...
# 72124  An Unlikely Contender Rises in France as the A...      0
# 72126  Determined to kill: Can tough gun laws end mas...      0
# 72129  Russians steal research on Trump in hack of U....      0
# 72131  Migrants Refuse To Leave Train At Refugee Camp...      0
# 72132  Trump tussle gives unpopular Mexican leader mu...      0
#
# [35028 rows x 2 columns]

# %%
from wordcloud import WordCloud
FakeCon = ' '.join(con for con in dfFake['training_feature'])
wordcloud = WordCloud(background_color='white', 
    max_words=300,
    width=800, 
    height=400,).generate(FakeCon)
plt.figure(figsize=(20, 10))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis("off")
plt.show()

# %%
dfTrue = df[df['label'] == 1]
dfTrue
# Out:
#                                         training_feature  label
# 0      LAW ENFORCEMENT ON HIGH ALERT Following Threat...      1
# 1         Did they post their votes for Hillary already?      1
# 2      UNBELIEVABLE! OBAMA’S ATTORNEY GENERAL SAYS MO...      1
# 4      SATAN 2: Russia unvelis an image of its terrif...      1
# 5      About Time! Christian Group Sues Amazon and SP...      1
# ...                                                  ...    ...
# 72125  WOW! JILL STEIN’S ‘FIRESIDE CHAT’ Exposes Her ...      1
# 72127  WIKILEAKS EMAIL SHOWS CLINTON FOUNDATION FUNDS...      1
# 72128  JUDGE JEANINE SOUNDS FREE SPEECH ALARM: “They ...      1
# 72130   WATCH: Giuliani Demands That Democrats Apolog...      1
# 72133  Goldman Sachs Endorses Hillary Clinton For Pre...      1
#
# [37106 rows x 2 columns]

# %%
from wordcloud import WordCloud
FakeCon = ' '.join(con for con in dfTrue['training_feature'])
wordcloud = WordCloud(background_color='white', 
    max_words=300,
    width=800, 
    height=400,).generate(FakeCon)
plt.figure(figsize=(20, 10))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis("off")
plt.show()

# %%
import re
import nltk
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
from nltk.stem import PorterStemmer
from sklearn.feature_extraction.text import TfidfVectorizer

# Download NLTK resources
nltk.download(['stopwords'])
nltk.download('punkt')
# Out:
# [nltk_data] <urlopen error [Errno 11001] getaddrinfo failed>
# [nltk_data] Error loading punkt: <urlopen error [Errno 11001]
# [nltk_data]     getaddrinfo failed>
# False

# %%
samplet = df['training_feature'].iloc[5]
print(samplet)
wordst = word_tokenize(samplet) 
wordst
# Out:
# About Time! Christian Group Sues Amazon and SPLC for Designation as Hate GroupAll we can say on this one is it s about time someone sued the Southern Poverty Law Center!On Tuesday, D. James Kennedy Ministries (DJKM) filed a lawsuit against the Southern Poverty Law Center (SPLC), the charity navigation organization GuideStar, and Amazon, for defamation, religious discrimination, and trafficking in falsehood. The SPLC listed DJKM as a  hate group,  while GuideStar also categorized it in those terms, and Amazon kept the ministry off of its charity donation program, Amazon Smile. We embarked today on a journey to right a terrible wrong,  Dr. Frank Wright, president and CEO at DJKM, said in a statement Tuesday.  Those who knowingly label Christian ministries as  hate  groups, solely for subscribing to the historic Christian faith, are either woefully uninformed or willfully deceitful. In the case of the Southern Poverty Law Center, our lawsuit alleges the latter. The SPLC has labeled DJKM an  anti-LGBT hate group  for its opposition to same-sex marriage and transgenderism.  These false and illegal characterizations have a chilling effect on the free exercise of religion and on religious free speech for all people of faith,  Wright declared. After having given the SPLC an opportunity to retract, we have undertaken this legal action, seeking a trial by a jury of our peers, to preserve our own rights under the law and to defend the religious free speech rights of all Americans,  the DJKM president concluded.The lawsuit laid out charges against the SPLC, GuideStar, and Amazon.Read more: PJM
# ['About',
#  'Time',
#  '!',
#  'Christian',
#  'Group',
#  'Sues',
#  'Amazon',
#  'and',
#  'SPLC',
#  'for',
#  'Designation',
#  'as',
#  'Hate',
#  'GroupAll',
#  'we',
#  'can',
#  'say',
#  'on',
#  'this',
#  'one',
#  'is',
#  'it',
#  's',
#  'about',
#  'time',
#  'someone',
#  'sued',
#  'the',
#  'Southern',
#  'Poverty',
#  'Law',
#  'Center',
#  '!',
#  'On',
#  'Tuesday',
#  ',',
#  'D.',
#  'James',
#  'Kennedy',
#  'Ministries',
#  '(',
#  'DJKM',
#  ')',
#  'filed',
#  'a',
#  'lawsuit',
#  'against',
#  'the',
#  'Southern',
#  'Poverty',
#  'Law',
#  'Center',
#  '(',
#  'SPLC',
#  ')',
#  ',',
#  'the',
#  'charity',
#  'navigation',
#  'organization',
#  'GuideStar',
#  ',',
#  'and',
#  'Amazon',
#  ',',
#  'for',
#  'defamation',
#  ',',
#  'religious',
#  'discrimination',
#  ',',
#  'and',
#  'trafficking',
#  'in',
#  'falsehood',
#  '.',
#  'The',
#  'SPLC',
#  'listed',
#  'DJKM',
#  'as',
#  'a',
#  'hate',
#  'group',
#  ',',
#  'while',
#  'GuideStar',
#  'also',
#  'categorized',
#  'it',
#  'in',
#  'those',
#  'terms',
#  ',',
#  'and',
#  'Amazon',
#  'kept',
#  'the',
#  'ministry',
#  'off',
#  'of',
#  'its',
#  'charity',
#  'donation',
#  'program',
#  ',',
#  'Amazon',
#  'Smile',
#  '.',
#  'We',
#  'embarked',
#  'today',
#  'on',
#  'a',
#  'journey',
#  'to',
#  'right',
#  'a',
#  'terrible',
#  'wrong',
#  ',',
#  'Dr.',
#  'Frank',
#  'Wright',
#  ',',
#  'president',
#  'and',
#  'CEO',
#  'at',
#  'DJKM',
#  ',',
#  'said',
#  'in',
#  'a',
#  'statement',
#  'Tuesday',
#  '.',
#  'Those',
#  'who',
#  'knowingly',
#  'label',
#  'Christian',
#  'ministries',
#  'as',
#  'hate',
#  'groups',
#  ',',
#  'solely',
#  'for',
#  'subscribing',
#  'to',
#  'the',
#  'historic',
#  'Christian',
#  'faith',
#  ',',
#  'are',
#  'either',
#  'woefully',
#  'uninformed',
#  'or',
#  'willfully',
#  'deceitful',
#  '.',
#  'In',
#  'the',
#  'case',
#  'of',
#  'the',
#  'Southern',
#  'Poverty',
#  'Law',
#  'Center',
#  ',',
#  'our',
#  'lawsuit',
#  'alleges',
#  'the',
#  'latter',
#  '.',
#  'The',
#  'SPLC',
#  'has',
#  'labeled',
#  'DJKM',
#  'an',
#  'anti-LGBT',
#  'hate',
#  'group',
#  'for',
#  'its',
#  'opposition',
#  'to',
#  'same-sex',
#  'marriage',
#  'and',
#  'transgenderism',
#  '.',
#  'These',
#  'false',
#  'and',
#  'illegal',
#  'characterizations',
#  'have',
#  'a',
#  'chilling',
#  'effect',
#  'on',
#  'the',
#  'free',
#  'exercise',
#  'of',
#  'religion',
#  'and',
#  'on',
#  'religious',
#  'free',
#  'speech',
#  'for',
#  'all',
#  'people',
#  'of',
#  'faith',
#  ',',
#  'Wright',
#  'declared',
#  '.',
#  'After',
#  'having',
#  'given',
#  'the',
#  'SPLC',
#  'an',
#  'opportunity',
#  'to',
#  'retract',
#  ',',
#  'we',
#  'have',
#  'undertaken',
#  'this',
#  'legal',
#  'action',
#  ',',
#  'seeking',
#  'a',
#  'trial',
#  'by',
#  'a',
#  'jury',
#  'of',
#  'our',
#  'peers',
#  ',',
#  'to',
#  'preserve',
#  'our',
#  'own',
#  'rights',
#  'under',
#  'the',
#  'law',
#  'and',
#  'to',
#  'defend',
#  'the',
#  'religious',
#  'free',
#  'speech',
#  'rights',
#  'of',
#  'all',
#  'Americans',
#  ',',
#  'the',
#  'DJKM',
#  'president',
#  'concluded.The',
#  'lawsuit',
#  'laid',
#  'out',
#  'charges',
#  'against',
#  'the',
#  'SPLC',
#  ',',
#  'GuideStar',
#  ',',
#  'and',
#  'Amazon.Read',
#  'more',
#  ':',
#  'PJM']

# %%
from nltk.corpus import stopwords
stop_words = set(stopwords.words('english'))
print(stop_words)
print("Before stopwords:",wordst)
wordss = [word for word in wordst if word not in stop_words]
print("after stopwords",wordss)
# Out:
# {'its', 'whom', "wouldn't", 'while', 'most', 'by', 'some', 'they', 'hers', 'no', 'himself', "you're", "didn't", 'more', 'is', 'all', 'now', 'o', 'mightn', 'such', 'this', 'herself', 'myself', 'are', 'don', 're', "weren't", 'you', 'up', "doesn't", 'only', 'themselves', 'because', 'at', 'where', 'between', 'isn', "isn't", 'as', 'needn', 'can', 'had', 'for', 'me', 'an', 'shan', "you'll", 'very', "haven't", 'm', 'of', 'mustn', 'she', 'have', 'nor', 'yours', 'haven', 'there', "shouldn't", 'shouldn', 'ma', 'yourself', 'which', "it's", 'own', 'theirs', 'our', "hadn't", 'who', 'below', 'too', 'the', 'having', "aren't", 'do', 'just', "that'll", 'until', 'hasn', 'were', 'didn', 'itself', 'on', 'during', 'so', 'those', 'i', 'few', 's', 'than', "you've", 'why', 'weren', 'same', 'again', 'it', 'what', 'from', 'or', 'been', 'not', 'out', 'other', 'ours', 'in', "couldn't", 'after', "you'd", 'your', 'off', 'above', "won't", 'down', 'their', 'under', "needn't", 'am', 'does', 'a', 'but', 'yourselves', 'has', 'her', 'we', 've', 'any', 'about', 'won', 'couldn', 'hadn', 'if', 'wouldn', 'through', 'with', 'should', 'then', 'wasn', 'over', 'his', 'was', 'being', 'aren', 'into', 'that', 'each', "mightn't", 'them', 'when', 'will', "hasn't", "mustn't", 'to', 'how', 'both', 'doing', 'd', 'doesn', 'ain', "should've", 'these', 'he', "wasn't", 'y', "she's", 'before', 'further', 'll', 'once', 'here', 'against', "don't", 'ourselves', "shan't", 'be', 'my', 'and', 'him', 't', 'did'}
# Before stopwords: ['About', 'Time', '!', 'Christian', 'Group', 'Sues', 'Amazon', 'and', 'SPLC', 'for', 'Designation', 'as', 'Hate', 'GroupAll', 'we', 'can', 'say', 'on', 'this', 'one', 'is', 'it', 's', 'about', 'time', 'someone', 'sued', 'the', 'Southern', 'Poverty', 'Law', 'Center', '!', 'On', 'Tuesday', ',', 'D.', 'James', 'Kennedy', 'Ministries', '(', 'DJKM', ')', 'filed', 'a', 'lawsuit', 'against', 'the', 'Southern', 'Poverty', 'Law', 'Center', '(', 'SPLC', ')', ',', 'the', 'charity', 'navigation', 'organization', 'GuideStar', ',', 'and', 'Amazon', ',', 'for', 'defamation', ',', 'religious', 'discrimination', ',', 'and', 'trafficking', 'in', 'falsehood', '.', 'The', 'SPLC', 'listed', 'DJKM', 'as', 'a', 'hate', 'group', ',', 'while', 'GuideStar', 'also', 'categorized', 'it', 'in', 'those', 'terms', ',', 'and', 'Amazon', 'kept', 'the', 'ministry', 'off', 'of', 'its', 'charity', 'donation', 'program', ',', 'Amazon', 'Smile', '.', 'We', 'embarked', 'today', 'on', 'a', 'journey', 'to', 'right', 'a', 'terrible', 'wrong', ',', 'Dr.', 'Frank', 'Wright', ',', 'president', 'and', 'CEO', 'at', 'DJKM', ',', 'said', 'in', 'a', 'statement', 'Tuesday', '.', 'Those', 'who', 'knowingly', 'label', 'Christian', 'ministries', 'as', 'hate', 'groups', ',', 'solely', 'for', 'subscribing', 'to', 'the', 'historic', 'Christian', 'faith', ',', 'are', 'either', 'woefully', 'uninformed', 'or', 'willfully', 'deceitful', '.', 'In', 'the', 'case', 'of', 'the', 'Southern', 'Poverty', 'Law', 'Center', ',', 'our', 'lawsuit', 'alleges', 'the', 'latter', '.', 'The', 'SPLC', 'has', 'labeled', 'DJKM', 'an', 'anti-LGBT', 'hate', 'group', 'for', 'its', 'opposition', 'to', 'same-sex', 'marriage', 'and', 'transgenderism', '.', 'These', 'false', 'and', 'illegal', 'characterizations', 'have', 'a', 'chilling', 'effect', 'on', 'the', 'free', 'exercise', 'of', 'religion', 'and', 'on', 'religious', 'free', 'speech', 'for', 'all', 'people', 'of', 'faith', ',', 'Wright', 'declared', '.', 'After', 'having', 'given', 'the', 'SPLC', 'an', 'opportunity', 'to', 'retract', ',', 'we', 'have', 'undertaken', 'this', 'legal', 'action', ',', 'seeking', 'a', 'trial', 'by', 'a', 'jury', 'of', 'our', 'peers', ',', 'to', 'preserve', 'our', 'own', 'rights', 'under', 'the', 'law', 'and', 'to', 'defend', 'the', 'religious', 'free', 'speech', 'rights', 'of', 'all', 'Americans', ',', 'the', 'DJKM', 'president', 'concluded.The', 'lawsuit', 'laid', 'out', 'charges', 'against', 'the', 'SPLC', ',', 'GuideStar', ',', 'and', 'Amazon.Read', 'more', ':', 'PJM']
# after stopwords ['About', 'Time', '!', 'Christian', 'Group', 'Sues', 'Amazon', 'SPLC', 'Designation', 'Hate', 'GroupAll', 'say', 'one', 'time', 'someone', 'sued', 'Southern', 'Poverty', 'Law', 'Center', '!', 'On', 'Tuesday', ',', 'D.', 'James', 'Kennedy', 'Ministries', '(', 'DJKM', ')', 'filed', 'lawsuit', 'Southern', 'Poverty', 'Law', 'Center', '(', 'SPLC', ')', ',', 'charity', 'navigation', 'organization', 'GuideStar', ',', 'Amazon', ',', 'defamation', ',', 'religious', 'discrimination', ',', 'trafficking', 'falsehood', '.', 'The', 'SPLC', 'listed', 'DJKM', 'hate', 'group', ',', 'GuideStar', 'also', 'categorized', 'terms', ',', 'Amazon', 'kept', 'ministry', 'charity', 'donation', 'program', ',', 'Amazon', 'Smile', '.', 'We', 'embarked', 'today', 'journey', 'right', 'terrible', 'wrong', ',', 'Dr.', 'Frank', 'Wright', ',', 'president', 'CEO', 'DJKM', ',', 'said', 'statement', 'Tuesday', '.', 'Those', 'knowingly', 'label', 'Christian', 'ministries', 'hate', 'groups', ',', 'solely', 'subscribing', 'historic', 'Christian', 'faith', ',', 'either', 'woefully', 'uninformed', 'willfully', 'deceitful', '.', 'In', 'case', 'Southern', 'Poverty', 'Law', 'Center', ',', 'lawsuit', 'alleges', 'latter', '.', 'The', 'SPLC', 'labeled', 'DJKM', 'anti-LGBT', 'hate', 'group', 'opposition', 'same-sex', 'marriage', 'transgenderism', '.', 'These', 'false', 'illegal', 'characterizations', 'chilling', 'effect', 'free', 'exercise', 'religion', 'religious', 'free', 'speech', 'people', 'faith', ',', 'Wright', 'declared', '.', 'After', 'given', 'SPLC', 'opportunity', 'retract', ',', 'undertaken', 'legal', 'action', ',', 'seeking', 'trial', 'jury', 'peers', ',', 'preserve', 'rights', 'law', 'defend', 'religious', 'free', 'speech', 'rights', 'Americans', ',', 'DJKM', 'president', 'concluded.The', 'lawsuit', 'laid', 'charges', 'SPLC', ',', 'GuideStar', ',', 'Amazon.Read', ':', 'PJM']

# %%
print("before stemming:",wordss)
stemmer = PorterStemmer()
print(stemmer)
wordsst = [stemmer.stem(word) for word in wordss]
print("after stemming",wordsst)
# Out:
# before stemming: ['About', 'Time', '!', 'Christian', 'Group', 'Sues', 'Amazon', 'SPLC', 'Designation', 'Hate', 'GroupAll', 'say', 'one', 'time', 'someone', 'sued', 'Southern', 'Poverty', 'Law', 'Center', '!', 'On', 'Tuesday', ',', 'D.', 'James', 'Kennedy', 'Ministries', '(', 'DJKM', ')', 'filed', 'lawsuit', 'Southern', 'Poverty', 'Law', 'Center', '(', 'SPLC', ')', ',', 'charity', 'navigation', 'organization', 'GuideStar', ',', 'Amazon', ',', 'defamation', ',', 'religious', 'discrimination', ',', 'trafficking', 'falsehood', '.', 'The', 'SPLC', 'listed', 'DJKM', 'hate', 'group', ',', 'GuideStar', 'also', 'categorized', 'terms', ',', 'Amazon', 'kept', 'ministry', 'charity', 'donation', 'program', ',', 'Amazon', 'Smile', '.', 'We', 'embarked', 'today', 'journey', 'right', 'terrible', 'wrong', ',', 'Dr.', 'Frank', 'Wright', ',', 'president', 'CEO', 'DJKM', ',', 'said', 'statement', 'Tuesday', '.', 'Those', 'knowingly', 'label', 'Christian', 'ministries', 'hate', 'groups', ',', 'solely', 'subscribing', 'historic', 'Christian', 'faith', ',', 'either', 'woefully', 'uninformed', 'willfully', 'deceitful', '.', 'In', 'case', 'Southern', 'Poverty', 'Law', 'Center', ',', 'lawsuit', 'alleges', 'latter', '.', 'The', 'SPLC', 'labeled', 'DJKM', 'anti-LGBT', 'hate', 'group', 'opposition', 'same-sex', 'marriage', 'transgenderism', '.', 'These', 'false', 'illegal', 'characterizations', 'chilling', 'effect', 'free', 'exercise', 'religion', 'religious', 'free', 'speech', 'people', 'faith', ',', 'Wright', 'declared', '.', 'After', 'given', 'SPLC', 'opportunity', 'retract', ',', 'undertaken', 'legal', 'action', ',', 'seeking', 'trial', 'jury', 'peers', ',', 'preserve', 'rights', 'law', 'defend', 'religious', 'free', 'speech', 'rights', 'Americans', ',', 'DJKM', 'president', 'concluded.The', 'lawsuit', 'laid', 'charges', 'SPLC', ',', 'GuideStar', ',', 'Amazon.Read', ':', 'PJM']
# <PorterStemmer>
# after stemming ['about', 'time', '!', 'christian', 'group', 'sue', 'amazon', 'splc', 'design', 'hate', 'groupal', 'say', 'one', 'time', 'someon', 'su', 'southern', 'poverti', 'law', 'center', '!', 'on', 'tuesday', ',', 'd.', 'jame', 'kennedi', 'ministri', '(', 'djkm', ')', 'file', 'lawsuit', 'southern', 'poverti', 'law', 'center', '(', 'splc', ')', ',', 'chariti', 'navig', 'organ', 'guidestar', ',', 'amazon', ',', 'defam', ',', 'religi', 'discrimin', ',', 'traffick', 'falsehood', '.', 'the', 'splc', 'list', 'djkm', 'hate', 'group', ',', 'guidestar', 'also', 'categor', 'term', ',', 'amazon', 'kept', 'ministri', 'chariti', 'donat', 'program', ',', 'amazon', 'smile', '.', 'we', 'embark', 'today', 'journey', 'right', 'terribl', 'wrong', ',', 'dr.', 'frank', 'wright', ',', 'presid', 'ceo', 'djkm', ',', 'said', 'statement', 'tuesday', '.', 'those', 'knowingli', 'label', 'christian', 'ministri', 'hate', 'group', ',', 'sole', 'subscrib', 'histor', 'christian', 'faith', ',', 'either', 'woefulli', 'uninform', 'will', 'deceit', '.', 'in', 'case', 'southern', 'poverti', 'law', 'center', ',', 'lawsuit', 'alleg', 'latter', '.', 'the', 'splc', 'label', 'djkm', 'anti-lgbt', 'hate', 'group', 'opposit', 'same-sex', 'marriag', 'transgender', '.', 'these', 'fals', 'illeg', 'character', 'chill', 'effect', 'free', 'exercis', 'religion', 'religi', 'free', 'speech', 'peopl', 'faith', ',', 'wright', 'declar', '.', 'after', 'given', 'splc', 'opportun', 'retract', ',', 'undertaken', 'legal', 'action', ',', 'seek', 'trial', 'juri', 'peer', ',', 'preserv', 'right', 'law', 'defend', 'religi', 'free', 'speech', 'right', 'american', ',', 'djkm', 'presid', 'concluded.th', 'lawsuit', 'laid', 'charg', 'splc', ',', 'guidestar', ',', 'amazon.read', ':', 'pjm']

# %%
def preprocess_text(text):
    text = re.sub(r"http\S+|www\S+|https\S+", "", text, flags=re.MULTILINE)

    # Remove special characters and numbers
    text = re.sub(r"[^\w\s]", "", text)
    text = re.sub(r"\d+", "", text)
    text = text.lower()
    
    # Tokenization
    words = word_tokenize(text)   
    
    # Remove stopwords
    stop_words = set(stopwords.words('english'))
    words = [word for word in words if word not in stop_words]

    # Stemming (you can use lemmatization instead if preferred)
    stemmer = PorterStemmer()
    words = [stemmer.stem(word) for word in words]
    # Join the words back into a string 
    preprocessed_text = ' '.join(words)
    return preprocessed_text
df['preprocessed_text'] = df['training_feature'].apply(preprocess_text)

# %%
df
# Out:
#                                         training_feature  label  \
# 0      LAW ENFORCEMENT ON HIGH ALERT Following Threat...      1
# 1         Did they post their votes for Hillary already?      1
# 2      UNBELIEVABLE! OBAMA’S ATTORNEY GENERAL SAYS MO...      1
# 3      Bobby Jindal, raised Hindu, uses story of Chri...      0
# 4      SATAN 2: Russia unvelis an image of its terrif...      1
# ...                                                  ...    ...
# 72129  Russians steal research on Trump in hack of U....      0
# 72130   WATCH: Giuliani Demands That Democrats Apolog...      1
# 72131  Migrants Refuse To Leave Train At Refugee Camp...      0
# 72132  Trump tussle gives unpopular Mexican leader mu...      0
# 72133  Goldman Sachs Endorses Hillary Clinton For Pre...      1
#
#                                        preprocessed_text
# 0      law enforc high alert follow threat cop white ...
# 1                              post vote hillari alreadi
# 2      unbeliev obama attorney gener say charlott rio...
# 3      bobbi jindal rais hindu use stori christian co...
# 4      satan russia unv imag terrifi new supernuk wes...
# ...                                                  ...
# 72129  russian steal research trump hack us democrat ...
# 72130  watch giuliani demand democrat apolog trump ra...
# 72131  migrant refus leav train refuge camp hungarymi...
# 72132  trump tussl give unpopular mexican leader much...
# 72133  goldman sach endors hillari clinton presidentg...
#
# [72134 rows x 3 columns]

# %%
x = df['preprocessed_text'].values
y = df['label']

# %%
vectorizern= TfidfVectorizer(ngram_range=(2,3),max_features=1500)
Xx=vectorizern.fit_transform(x)

# %%
feautrenames=vectorizern.get_feature_names_out() 
print(feautrenames)
# Out:
# ['abc news' 'access pipelin' 'accord new' ... 'young peopl' 'your go'
#  'youv got']

# %%
vectorizer= TfidfVectorizer()
X=vectorizer.fit_transform(x)

# %%
x_train, x_test, y_train, y_test= train_test_split(x, y, test_size=0.15, stratify=y, random_state=42)

# %%
print(len(x_test),len(x_train),len(y_train),len(y_test))
# Out:
# 10821 61313 61313 10821

# %%
print(x_train)
# Out:
# ['donald trump suggest second amend peopl could act hillari clinton new york timeswilmington n c donald j trump tuesday appear rais possibl gun right support could take matter hand hillari clinton elect presid appoint judg favor stricter gun control measur repeat content mr clinton want abolish right bear arm mr trump warn ralli would horribl day mr clinton elect got appoint tiebreak suprem court justic get pick judg noth folk mr trump said crowd began boo quickli ad although second amend peopl mayb dont know obliqu mr trump remark quickli elicit wave condemn democrat gun control advoc other accus suggest violenc mr clinton liber jurist bernic king daughter rev dr martin luther king jr call mr trump word distast disturb danger mr clinton run mate senat tim kain virginia express disbelief nobodi seek leadership posit especi presid leadership countri anyth counten violenc that say mr kain said austin tex call mr trump remark window soul person temperament suit task dan gross presid bradi campaign center prevent gun violenc endors mr clinton said mr trump statement repuls liter use second amend cover encourag peopl kill someon disagre trump violenc becom standard talk point common punch line even campaign strategi mr gross said paul ryan republican hous speaker tens relationship mr trump told report tuesday night remark sound like joke gone bad ad never joke hope clear quickli mr trump campaign treat remark joke instead insist mere urg gun right support vote bloc mr clinton second amend peopl tremend power unit told cb affili north carolina late tuesday interview fox news mr trump grew adam interpret said ad mean give break ralli earlier day mr trump actual discuss could happen mr clinton presid elect even mani audienc seem caught surpris video show man mr trump shoulder go turn companion appar disbelief mr trump made remark uproar mr trump remark came campaign face seri public opinion survey show quickli lose ground mr clinton day campaign call deliveri prepar econom speech detroit evid newfound polit disciplin mr trump fellow oppon gun control stood focus depict mr clinton threat second amend donald trump absolut correct said jennif baker strategist nation rifl associ hillari clinton elect noth stop nomin suprem court justic vote overturn individu right citizen gun home protect associ also began run new commerci character mr clinton one wealthiest women polit call hypocrit favor gun restrict protect arm guard year gun polici ad say would leav ordinari peopl defenseless veil refer gun violenc trip candid sharron angl nevada republican challeng senat major leader time harri reid sever damag unsuccess candidaci discuss import second amend read constitut found father intend stop tyranni said ad defend know im hope get second amend remedi hope vote cure harri reid problem mr clinton learn hard way june shortli conced defeat democrat primari contest barack obama defend persever way critic said allud possibl mr obama could gun rememb bobbi kennedi assassin june california mr clinton said apolog hour later mr trump repeat violent insinu later event fayettevil n c senat chri murphi democrat connecticut champion gun control sinc sandi hook mass shoot state call mr trump remark disgust embarrass sad isnt play mr murphi wrote unstabl peopl power gun unhing hatr hillari listen realdonaldtrump condemn mr trump critic across polit spectrum deep twitter conserv writer john podhoretz seri post wrote mr trump impli second amend support potenti assassin ad presid word mean noth import word spoken world repres eric swalwel democrat california wrote twitter secret servic investig mr trump make death threat mr clinton donald trump suggest someon kill sec clinton must take peopl word secret servic spokesman refus identifi said agenc awar comment elabor other seiz mr trump remark occas mockeri senat elizabeth warren democrat massachusett wrote twitter mr trump make death threat he pathet coward cant handl fact he lose girl mr trump campaign event grow ...
#  'gop voter like trump despit see religi pollreut republican presidenti frontrunn donald trump seen religi republican candid republican think could good presid anyway new nationwid poll found wednesday pew research center poll found percent republican voter thought trump identifi presbyterian somewhat religi anoth percent found thricemarri real estat tycoon religi percent found religi poll also found percent republican voter thought trump would good great presid even though voter view religi asset us presidenti candid especi republican contrast percent republican voter found contend ben carson seventhday adventist somewhat religi percent found us senat ted cruz texa southern baptist run second trump recent poll percent republican voter found cruz carson religi poll also found percent republican consid presid share religi belief somewhat import compar percent democrat democrat side percent democrat voter view former secretari state hillari clinton methodist somewhat religi percent democrat think us senat berni sander vermont jewish candid seen religi parti poll found biggest partisan gap view hillari clinton percent republican think clinton somewhat religi survey also found share american reserv vote atheist presid declin percent american said would less like support atheist presid number declin percent poll found survey conduct jan jan among sampl adult state margin error plu minu percent total sampl report mari wisniewski edit jeffrey benko sap sponsor coverag independ produc staff reuter news agenc'
#  'crisi conscienc obama free score drug offend prison includ lifer day electionhom solut crisi conscienc obama free score drug offend prison includ lifer day elect crisi conscienc obama free score drug offend prison includ lifer day elect matt agorist octob comment prison rapist thiev murder lock someon smoke plant make happi your fuck crimin joe rogan washington dc timeless word joe rogan seem take toll conscienc american politician kidnap lock peopl cage person choic action harm one evil act politician figur least pander public demand either way result despit larg continu drug war drastic increas raid medic marijuana facil compar predecessor barack obama somehow manag dupe peopl think pro legal pot reign come end seem revers cours year obama blown lot smoke pun intend came view war drug he play mr nice guy heavili militar govern task forc laid wast right properti peac peopl tri help fellow man grow medic marijuana obama polic america feder program acquir mrap grenad launcher even apach attack chopper use enforc immor uneth drug law howev one even almighti barack obama stop idea whose time come peopl spoken politician continu call imprison nonviol individu person choic expos vile obstin tyrant appar notion made ear majesti barack obama recent show human he freed sever dozen nonviol drug offend accord reason magazin latest batch commut rais obama total far nearli involv nonviol drug offend commut issu recent predecessor combin accord white hous commut sinc begin ever done presid singl yearnot surpris sinc obama commut strikingli backload percent come last year offic percent second half second term shorten one sentenc first term chart show either obama conscienc weigh polit pressur win accord report reason obama clearli tri hard make lost time speech tuesday deputi attorney gener salli yate said mani commut come wednesday white hous counsel neil eggleston said obama commit use clemenc author remaind time offic maintain month rate novemb decemb januari total around pick pace could still reach thousand predict even commut would repres percent petit obama receiv make slightli merci richard nixon measur nevertheless would repres huge improv obama stood six month ago time state admit wrong innoc peopl freed cage oppress win freedom one life spare horrid fate cage like anim possess ingest plant grow ground good news howev ten thousand nonviol drug offend lock steel cage across countri mani possess alon slow rusti cog bureaucrat leviathan cant turn fast enough everi nonviol drug offend presid free five thrown lock drug user proven quit profit ventur much easier walk street corner shakedown teenag may illeg plant pocket examin evid rape murder case socal privat prison know subsequ found nich immor war drug term privat prison farc getgo truli privat prison would sole fund taxpay dollar privat prison noth fascist mixtur state corpor complet depend upon extort factor state ie taxat mean corpor susten truli privat prison would neg incent boost popul simpl fact particularli expens hous inmat contrari fascist aptli corporatist prison contractu requir occup rate requir occup rate creat de facto demand crimin think second need demand peopl commit crime creat corporatist arrang implic associ demand peopl commit crime horrifi creat complet immor demand crimin lead situat find today peopl otherwis entir innoc label crimin person choic thrown cage wit viciou cycl law enforc must creat arrest crimin corporatist prison system constantli demand prison polic prison corpor know without war drug windfal money car hous ceas exist want know profit ruin live throw marijuana user cage need look bribe also known lobbi politician keep war drug aliv list top five industri need lock cage possess plant order ensur job secur polic union come number one contributor politician vote lock cage plant polic risk take massiv pay cut lose expens militar toy without war drug privat prison corpor surpris corporatist prison lobbi constantli push stricter law keep stream tax ...
#  ...
#  'fbi warn philli colleg threat monday need knowth fbi photo warn drexel univers colleg univers philli area warn see everyon littl confus tomorrow colleg class twitter messag look someth like one email alert sent student awar see someth say someth patrol increas everyon vigil fbi issu warn philadelphia colleg possibl threat monday know far threat relat social network post fbi issu safeti advisori colleg philadelphia area threat relat social media post threaten violenc univers area shoot umpqua commun colleg fbi take abund caution advisori state fbi receiv similar post throughout countryaccord relat thread reddit warn may made post made chan talk violenc philadelphia monday octob thread read part beta rebellion begun shoot oregon first post state pm octob someon els would take arm colleg philadelphia anyon area encourag stay home messag repost imgur read warn monday around pm easternaccord univers pennsylvania advisori post threat specif monday octob around pm eastern pm central specif univers specifi univers colleg area advis take caution lookout anyon suspici knowledg specif threat fbi state knowledg specif threat drexel univers said go increas patrol monday univers report go lookout anyth suspici student sure warninga student la sall univers told philli mag idea inform suppos campu time threat know look shoulder student meanwhil said plan skip class tomorrow time other concern gotten warn yetoth student concern sure actual receiv warn yet even though attend colleg area one student attend univers scienc post twitter wonder receiv news warn yet la sall univers student told philli mag found warn saw safeti advisori univers websit one sent text email warn philli mag state fbi respond request commentvia heavi'
#  'said find denzel washington meek mill kesha sayemail ever wonder what mind today notabl peopl well dont miss unbeliev roundup best talk quot day god isnt big man sit cloud he mediums hang onto cloud dear life denzel washington faith peopl around get advanc arent real friend your atlant tri catch big kahuna mola mola sunfish your day realiz fame doesnt bring everyth sure wont bring damn sunfish starboard bow cri much boat fill tear sink yell help endur swimmer swim new york find drag ashor that real friend meek mill music paper towel use soak spill water silenc kesha'
#  'haywir hack media refus believ trump russia comment sarcasticth uproar donald trump latest comment classic case mediagener outrag newspap airwav shock horror trump would appeal russia furnish hillari clinton hack email line seem obvious sarcast watch trump presser democrat convent philadelphia didnt see tsunami come mayb im wrong longtim trumpwatch that came think media coverag minut believ republican nomine dead seriou urg adversari unit state commit complet act espionag democrat oppon believ trump clinic insan think mani journalist comment view bit unhing that make sens think trump wall seem perfectli plausibl other believ dont believ trump realli meant think step remark happi bash look trump say lot incendiari thing comment mexican muslim like get troubl fair game critic one differ russia your listen hope your abl find email miss trump said ad press would love trump master cours say thing far enough line drive stori day case mean keep focu email clinton delet privat server pundit politician debat whether cross linesiphon cover convent speech presid obama vice presid biden bill clinton other trump say sarcast dont even know whether russian behind hack what strike coverag bare acknowledg could open question new york time headlin donald trump appeal russia shock foreign polici expert simpli preced presidenti candid publicli appeal foreign adversari interven elect behalf washington post lead republican nomine donald trump plead directli wednesday russian govern meddl us presidenti elect find releas ten thousand privat email democrat oppon hillari clinton extraordinari perhap unpreced maneuv american polit politico lead donald trump call russia hack hillari clinton email shock flabbergast appal lawmak nation secur expert across polit spectrum one say tantamount treason possibl trump sarcast joke cnn carol costello ask panel respons even wasnt funni profession politician avoid sarcasm avoid utter word creat uproar trump delight support love detractor view reckless media never seem get enough howard kurtz fox news analyst host mediabuzz sunday pm et author five book base washington follow howardkurtz click inform howard kurtz']

# %%
tfidf_vectorizer = TfidfVectorizer(max_features=5000)
x_train = tfidf_vectorizer.fit_transform(x_train)
x_test = tfidf_vectorizer.transform(x_test)

# %%
from sklearn.linear_model import LogisticRegression
model=LogisticRegression(max_iter=500)
model.fit(x_train,y_train)
# Out:
# LogisticRegression(max_iter=500)

# %%
ypred=model.predict(x_test)
from sklearn.metrics import confusion_matrix
cm = confusion_matrix(ypred,y_test)
print(cm)
# Out:
# [[4912  307]
#  [ 343 5259]]

# %%
plt.figure(figsize=(6,4))
sns.heatmap(cm,annot=True,fmt='d',xticklabels=['REAL','Not REAL'],
yticklabels=['REAL','Not REAL'])
plt.ylabel('Prediction',fontsize=15)
plt.xlabel('Actual',fontsize=15)
plt.title('Confusion Matrix',fontsize=17)
plt.show()

# %%
from sklearn.model_selection import StratifiedKFold
from sklearn.model_selection import cross_val_score
k =50
kf = StratifiedKFold(n_splits=k)   
mod = cross_val_score(model,X, y, scoring='accuracy', cv=kf)
print("accuracy:",np.max(mod)*100)  
p= cross_val_score(model,X, y, scoring='precision',cv=kf)
print("precision:",np.max(p)*100)
f1 = cross_val_score(model,X, y, scoring='f1',cv=kf)
print("f1_score:",np.max(f1)*100)
re= cross_val_score(model,X, y, scoring='recall',cv=kf)
print("Recall:",np.max(re)*100)
# Out:
# accuracy: 96.11650485436894
# precision: 95.97855227882037
# f1_score: 96.23655913978496
# Recall: 97.30458221024259

# %%
from sklearn.model_selection import cross_val_predict
from sklearn.metrics import classification_report
kf3=cross_val_predict(model,X,y,cv=kf)
clf3=classification_report(y,kf3,output_dict=True)
b=pd.DataFrame(clf3).transpose()
b
# Out:
#               precision    recall  f1-score       support
# 0              0.956666  0.939705  0.948110  35028.000000
# 1              0.944019  0.959818  0.951853  37106.000000
# accuracy       0.950051  0.950051  0.950051      0.950051
# macro avg      0.950342  0.949762  0.949981  72134.000000
# weighted avg   0.950160  0.950051  0.950035  72134.000000

# %%
tn, fp, fn, tp = cm.ravel()
sensitivity = tp / (tp + fn)
specificity = tn / (tn + fp)
print(sensitivity)
print(specificity)
# Out:
# 0.9387718671902892
# 0.9411764705882353

# %%
from sklearn.metrics import roc_curve, auc
fpr, tpr, thresholds = roc_curve(y_test, ypred)

# Compute the area under the ROC curve (AUC)
roc_auc = auc(fpr, tpr)

# Plot the ROC curve
plt.figure(figsize=(8, 8))
plt.plot(fpr, tpr, color='darkorange', lw=2, label=f'ROC curve (AUC = {roc_auc:.2f})')
plt.plot([0, 1], [0, 1], color='navy', lw=2, linestyle='--', label='Random Guessing')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver Operating Characteristic (ROC) Curve')
plt.legend(loc='lower right')
plt.show()

# %% [markdown]
# RandomForest

# %%
from sklearn.ensemble import RandomForestClassifier
rf_model = RandomForestClassifier(n_estimators=100, random_state=42,max_depth=70)
rf_model.fit(x_train, y_train)
# Out:
# RandomForestClassifier(max_depth=70, random_state=42)

# %%
ypred=rf_model.predict(x_test) 
from sklearn.metrics import confusion_matrix
cm = confusion_matrix(ypred,y_test)
print(cm)
# Out:
# [[4878  209]
#  [ 377 5357]]

# %%
from sklearn.metrics import classification_report
clf5=classification_report(ypred,y_test,output_dict=True)
e=pd.DataFrame(clf5).transpose()
e
# Out:
#               precision    recall  f1-score       support
# 0              0.928259  0.958915  0.943338   5087.000000
# 1              0.962451  0.934252  0.948142   5734.000000
# accuracy       0.945846  0.945846  0.945846      0.945846
# macro avg      0.945355  0.946583  0.945740  10821.000000
# weighted avg   0.946377  0.945846  0.945883  10821.000000

# %%
plt.figure(figsize=(6,4))
sns.heatmap(cm,annot=True,fmt='d',xticklabels=['REAL','Not REAL'],
yticklabels=['REAL','Not REAL'])
plt.ylabel('Prediction',fontsize=15)
plt.xlabel('Actual',fontsize=15)
plt.title('Confusion Matrix',fontsize=17)
plt.show()

# %%
from sklearn.model_selection import StratifiedKFold
from sklearn.model_selection import cross_val_score
k =15
kf = StratifiedKFold(n_splits=k)   
mod = cross_val_score(rf_model,X, y, scoring='accuracy', cv=kf)
print("accuracy:",np.max(mod)*100)  
p= cross_val_score(rf_model,X, y, scoring='precision',cv=kf)
print("precision:",np.mean(p)*100)
f1 = cross_val_score(rf_model,X, y, scoring='f1',cv=kf)
print("f1_score:",np.mean(f1)*100)
re= cross_val_score(rf_model,X, y, scoring='recall',cv=kf)
print("Recall:",np.mean(re)*100)
# Out:
# accuracy: 0.945846040107199
# precision: 0.9342518311824206
# f1-score 0.948141592920354
# recall 0.9624505928853755

# %%
tn, fp, fn, tp = cm.ravel()
sensitivity = tp / (tp + fn)
specificity = tn / (tn + fp)
print(sensitivity)
print(specificity)
# Out:
# 0.9342518311824206
# 0.9589148810693926

# %%
from sklearn.metrics import roc_curve, auc
fpr, tpr, thresholds = roc_curve(y_test, ypred)

# Compute the area under the ROC curve (AUC)
roc_auc = auc(fpr, tpr)

# Plot the ROC curve
plt.figure(figsize=(8, 8))
plt.plot(fpr, tpr, color='darkorange', lw=2, label=f'ROC curve (AUC = {roc_auc:.2f})')
plt.plot([0, 1], [0, 1], color='navy', lw=2, linestyle='--', label='Random Guessing')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver Operating Characteristic (ROC) Curve')
plt.legend(loc='lower right')
plt.show()

# %% [markdown]
# XGB Classifier

# %%
from xgboost import XGBClassifier
xgb_model = XGBClassifier(learning_rate=0.2, n_estimators=20,  eval_metric="logloss", max_depth=10)
xgb_model.fit(x_train, y_train)

# %%
ypred=xgb_model.predict(x_test)
cm = confusion_matrix(ypred,y_test)
print(cm)

# %%
clf5=classification_report(y_pred,y_test,output_dict=True)
e=pd.DataFrame(clf5).transpose()
e

# %%
plt.figure(figsize=(6,4))
sns.heatmap(cm,annot=True,fmt='d',xticklabels=['REAL','Not REAL'],
yticklabels=['REAL','Not REAL'])
plt.ylabel('Prediction',fontsize=15)
plt.xlabel('Actual',fontsize=15)
plt.title('Confusion Matrix',fontsize=17)
plt.show()

# %%
from sklearn.model_selection import KFold
from sklearn.model_selection import cross_val_score
k =10
kf = KFold(n_splits=k)
mod = cross_val_score(xgb_model,X, y, scoring='accuracy', cv=kf)
print("accuracy:",np.mean(mod)*100)
p= cross_val_score(xgb_model,X, y, scoring='precision',cv=kf)
print("precision:",np.mean(p)*100)
f1 = cross_val_score(xgb_model,X, y, scoring='f1',cv=kf)
print("f1_score:",np.mean(f1)*100)
re= cross_val_score(xgb_model,X, y, scoring='recall',cv=kf)
print("Recall:",np.mean(re)*100)
# Out:
# accuracy: 0.9561962850013862
# precision: 0.9441730635031402
# f1-score 0.9580456718003186
# recall 0.9723320158102767

# %%
tn, fp, fn, tp = cm.ravel()
sensitivity = tp / (tp + fn)
specificity = tn / (tn + fp)
print(sensitivity)
print(specificity)
# Out:
# 0.9441730635031402
# 0.9697386519944979

# %%
from sklearn.metrics import roc_curve, auc
fpr, tpr, thresholds = roc_curve(y_test, ypred)

# Compute the area under the ROC curve (AUC)
roc_auc = auc(fpr, tpr)

# Plot the ROC curve
plt.figure(figsize=(8, 8))
plt.plot(fpr, tpr, color='darkorange', lw=2, label=f'ROC curve (AUC = {roc_auc:.2f})')
plt.plot([0, 1], [0, 1], color='navy', lw=2, linestyle='--', label='Random Guessing')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver Operating Characteristic (ROC) Curve')
plt.legend(loc='lower right')
plt.show()

# %% [markdown]
# MLP Classifier

# %%
from sklearn.neural_network import MLPClassifier
mlp_model = MLPClassifier(hidden_layer_sizes=(100,), max_iter=500, random_state=42, early_stopping=True, validation_fraction=0.1)
mlp_model.fit(x_train, y_train)
# Out:
# MLPClassifier(early_stopping=True, max_iter=500, random_state=42)

# %%
ypred = mlp_model.predict(x_test)
cm = confusion_matrix(ypred,y_test)
cm
# Out:
# array([[4930,  299],
#        [ 325, 5267]], dtype=int64)

# %%
clf5=classification_report(ypred,y_test,output_dict=True)
e=pd.DataFrame(clf5).transpose()
e
# Out:
#               precision    recall  f1-score       support
# 0              0.938154  0.942819  0.940481   5229.000000
# 1              0.946281  0.941881  0.944076   5592.000000
# accuracy       0.942334  0.942334  0.942334      0.942334
# macro avg      0.942218  0.942350  0.942278  10821.000000
# weighted avg   0.942354  0.942334  0.942339  10821.000000

# %%
plt.figure(figsize=(6,4))
sns.heatmap(cm,annot=True,fmt='d',xticklabels=['REAL','Not REAL'],
yticklabels=['REAL','Not REAL'])
plt.ylabel('Prediction',fontsize=15)
plt.xlabel('Actual',fontsize=15)
plt.title('Confusion Matrix',fontsize=17)
plt.show()

# %%
from sklearn.model_selection import KFold
from sklearn.model_selection import cross_val_score
k =10
kf = KFold(n_splits=k)
mod = cross_val_score(mlp_model,X, y, scoring='accuracy', cv=kf)
print("accuracy:",np.mean(mod)*100)
p= cross_val_score(mlp_model,X, y, scoring='precision',cv=kf)
print("precision:",np.mean(p)*100)
f1 = cross_val_score(mlp_model,X, y, scoring='f1',cv=kf)
print("f1_score:",np.mean(f1)*100)
re= cross_val_score(mlp_model,X, y, scoring='recall',cv=kf)
print("Recall:",np.mean(re)*100)
# Out:
# accuracy: 0.9423343498752426
# precision: 0.9418812589413448
# f1-score 0.9440759992830258
# recall 0.9462809917355371

# %%
tn, fp, fn, tp = cm.ravel()
sensitivity = tp / (tp + fn)
specificity = tn / (tn + fp)
print(sensitivity)
print(specificity)
# Out:
# 0.9418812589413448
# 0.9428188946261236

# %%
from sklearn.metrics import roc_curve, auc
fpr, tpr, thresholds = roc_curve(y_test, ypred)

# Compute the area under the ROC curve (AUC)
roc_auc = auc(fpr, tpr)

# Plot the ROC curve
plt.figure(figsize=(8, 8))
plt.plot(fpr, tpr, color='darkorange', lw=2, label=f'ROC curve (AUC = {roc_auc:.2f})')
plt.plot([0, 1], [0, 1], color='navy', lw=2, linestyle='--', label='Random Guessing')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver Operating Characteristic (ROC) Curve')
plt.legend(loc='lower right')
plt.show()

# %% [markdown]
# BernouliNB

# %%
from sklearn.naive_bayes import BernoulliNB
bnb_model = BernoulliNB()
bnb_model.fit(x_train, y_train)
ypred = bnb_model.predict(x_test)

# %%
cm = confusion_matrix(ypred,y_test)
cm
# Out:
# array([[3655,  856],
#        [1600, 4710]], dtype=int64)

# %%
clf5=classification_report(ypred,y_test,output_dict=True)
e=pd.DataFrame(clf5).transpose()
e
# Out:
#               precision    recall  f1-score       support
# 0              0.695528  0.810242  0.748515   4511.000000
# 1              0.846209  0.746434  0.793196   6310.000000
# accuracy       0.773034  0.773034  0.773034      0.773034
# macro avg      0.770869  0.778338  0.770856  10821.000000
# weighted avg   0.783394  0.773034  0.774570  10821.000000

# %%
plt.figure(figsize=(6,4))
sns.heatmap(cm,annot=True,fmt='d',xticklabels=['REAL','Not REAL'],
yticklabels=['REAL','Not REAL'])
plt.ylabel('Prediction',fontsize=15)
plt.xlabel('Actual',fontsize=15)
plt.title('Confusion Matrix',fontsize=17)
plt.show()

# %%
from sklearn.model_selection import KFold
from sklearn.model_selection import cross_val_score
k =10
kf = KFold(n_splits=k)
mod = cross_val_score(bnb_model,X, y, scoring='accuracy', cv=kf)
print("accuracy:",np.mean(mod)*100)
p= cross_val_score(bnb_model,X, y, scoring='precision',cv=kf)
print("precision:",np.mean(p)*100)
f1 = cross_val_score(bnb_model,X, y, scoring='f1',cv=kf)
print("f1_score:",np.mean(f1)*100)
re= cross_val_score(bnb_model,X, y, scoring='recall',cv=kf)
print("Recall:",np.mean(re)*100)
# Out:
# accuracy: 86.11750047305078
# precision: 84.38781411958357
# f1_score: 86.9101499386056
# Recall: 89.59196130040873

# %%
tn, fp, fn, tp = cm.ravel()
sensitivity = tp / (tp + fn)
specificity = tn / (tn + fp)
print(sensitivity) 
print(specificity)
# Out:
# 0.7464342313787639
# 0.81024163156728

# %%
from sklearn.metrics import roc_curve, auc
fpr, tpr, thresholds = roc_curve(y_test, ypred)

# Compute the area under the ROC curve (AUC)
roc_auc = auc(fpr, tpr)

# Plot the ROC curve
plt.figure(figsize=(8, 8))
plt.plot(fpr, tpr, color='darkorange', lw=2, label=f'ROC curve (AUC = {roc_auc:.2f})')
plt.plot([0, 1], [0, 1], color='navy', lw=2, linestyle='--', label='Random Guessing')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver Operating Characteristic (ROC) Curve')
plt.legend(loc='lower right')
plt.show()

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
data_before = {

    'Model': ['Bernoulli NB','MLP Classifier','XGB Classifier','Random Forest'],
    'Accuracy': [85,90,95,89,],
}

data_after = {
    'Model': ['Bernoulli NB','MLP Classifier','XGB Classifier','Random Forest'],
    'Accuracy': [86,94,95,94],
}

# Create dataframes
dtfm_before = pd.DataFrame(data_before)
dtfm_after = pd.DataFrame(data_after)

# Set the Model column as the index for better plotting
dtfm_before.set_index('Model', inplace=True)
dtfm_after.set_index('Model', inplace=True)

# Create a bar graph
fig, axes = plt.subplots(nrows=1, ncols=1, figsize=(8, 8))
def plot_bargraph(ax, metric, title):
    before_values = dtfm_before[metric]
    after_values = dtfm_after[metric]
    models = dtfm_before.index

    index = np.arange(len(models))
    bar_width = 0.35

    ax.bar(index, before_values, width=bar_width, label='Existing_Model[Ref.1]', color='skyblue')
    ax.bar(index + bar_width, after_values, width=bar_width, label='Proposed Model', color='lightcoral')

    for i in range(len(models)):
        ax.text(index[i] - 0.05, before_values[i] + 1, f'{before_values[i]:.2f}', fontsize=8)
        ax.text(index[i] + bar_width - 0.05, after_values[i] + 1, f'{after_values[i]:.2f}', fontsize=8)

    ax.set_xlabel('Model')
    ax.set_ylabel(metric)
    ax.set_title(title)
    ax.set_xticks(index + bar_width / 2)
    ax.set_xticklabels(models)
    ax.legend()

plot_bargraph(axes, 'Accuracy', 'Accuracy Comparison')
plt.tight_layout()
plt.show()
# Out:
# C:\Users\madhu\AppData\Local\Temp\ipykernel_14964\1110273455.py:38: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   ax.text(index[i] - 0.05, before_values[i] + 1, f'{before_values[i]:.2f}', fontsize=8)
# C:\Users\madhu\AppData\Local\Temp\ipykernel_14964\1110273455.py:39: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   ax.text(index[i] + bar_width - 0.05, after_values[i] + 1, f'{after_values[i]:.2f}', fontsize=8)

# %%
import pandas as pd
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
'''data = {
    #'Model': ['LOGISTIC REGRESSIN', 'RANDOM FOREST','BernoulliNB,'MPL Classifier','XGB Classifier'],
    'Model':['Accuracy','MLP','XGB','RF','LR'],
    'Recall': [89,94,97,96,97],

}
dtfm= pd.DataFrame(data)
print(dtfm)
plt.figure(figsize=(12, 8))
plt.subplot(2, 2,1)
sns.barplot(x=dtfm['Model'], y=dtfm['Recall'], color='brown')
plt.title('Model Recall')
plt.show()  

'''
a=96.1165
b=95.9785
c=96.2365
d=97.3045
model_name = 'Logistic Regression'
fig, ax = plt.subplots(figsize=(6, 6))
metrics = ['Accuracy', 'Precision', 'F1-score','Recall']
values = [a,b,c,d]
bars = ax.bar(metrics, values, color=['pink','green','purple','red'])
for bar in bars:
    yval = bar.get_height()
    plt.text(bar.get_x() + bar.get_width()/2, yval, round(yval, 2), ha='center', va='bottom')
plt.title(f'{model_name} Metrics')
plt.ylabel('Score')
plt.ylim(0, 100)
plt.show()

# %%
import pickle
pickle.dump(tfidf_vectorizer, open('vectorizers.pkl', 'wb'))

# %%
filename = 'MY_MODEL.pkl'
pickle.dump(model, open(filename, 'wb'))
